# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("churn.csv")
df.describe()
# Out:
#          RowNumber    CustomerId  CreditScore          Age       Tenure  \
# count  3999.000000  3.999000e+03  3999.000000  3999.000000  3999.000000
# mean   2000.000000  1.568909e+07   650.135034    38.626657     5.526382
# std    1154.556192  7.703876e+04    97.399107    10.573259     4.017252
# min       1.000000  1.501234e+07   350.000000    18.000000     0.000000
# 25%    1000.500000  1.562813e+07   583.000000    32.000000     4.000000
# 50%    2000.000000  1.568924e+07   653.000000    37.000000     5.000000
# 75%    2999.500000  1.575232e+07   717.000000    44.000000     7.000000
# max    3999.000000  1.598766e+07   850.000000    88.000000    20.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count    3999.000000    3999.000000  3999.000000     3999.000000
# mean    77512.037089       2.359340     0.707927        0.510628
# std     62265.781812       1.493577     0.454773        0.499950
# min         0.000000       1.000000     0.000000        0.000000
# 25%         0.000000       1.000000     0.000000        0.000000
# 50%     97925.110000       1.000000     1.000000        1.000000
# 75%    128133.860000       4.000000     1.000000        1.000000
# max    250898.090000       4.000000     1.000000        1.000000
#
#        EstimatedSalary       Exited
# count      3999.000000  3999.000000
# mean     100536.523703     0.211553
# std       57576.014022     0.408461
# min          11.580000     0.000000
# 25%       51596.125000     0.000000
# 50%      100686.110000     0.000000
# 75%      149085.630000     0.000000
# max      199970.740000     1.000000

# %%
df
# Out:
#       RowNumber  CustomerId     Surname  CreditScore  Geography  Gender  Age  \
# 0             1    15261344         Kai          619      Japan    Male   38
# 1             2    15172846       Matty          608  Australia    Male   37
# 2             3    15207294       Motts          502      Japan    Male   38
# 3             4    15845928     SLeeeng          699      Japan    Male   39
# 4             5    15638792   SStevieun          850  Australia    Male   43
# ...         ...         ...         ...          ...        ...     ...  ...
# 3994       3995    15763097   Siciliano          809  Australia  Female   80
# 3995       3996    15633666     Efremov          701  Australia    Male   33
# 3996       3997    15718789  Brigstocke          604      Japan  Female   30
# 3997       3998    15690620  Olisaemeka          665      Japan  Female   39
# 3998       3999    15737071        Tang          639      Japan    Male   60
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          5       0.00              1          1               1
# 1          2   83807.86              1          0               1
# 2          4  159660.80              1          1               0
# 3          2       0.00              4          0               0
# 4          5  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 3994       4       0.00              4          0               1
# 3995       7  123870.07              1          1               0
# 3996       5       0.00              4          1               0
# 3997      20   46323.57              1          1               0
# 3998       5  162039.78              1          1               1
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 3994         34164.05       0
# 3995         97794.71       0
# 3996         75786.55       0
# 3997        136812.02       0
# 3998         84361.72       1
#
# [3999 rows x 14 columns]

# %%
sns.set_style(style = 'whitegrid')
plt.figure(figsize=(12, 10))

# %%
sns.countplot(x = 'Exited' , data = df)
plt.title("Distribution of Churn")
# Out:
# Text(0.5, 1.0, 'Distribution of Churn')

# %%
sns.histplot(data = df , x = 'Age',kde=True )
plt.title('Age Distribution')
# Out:
# Text(0.5, 1.0, 'Age Distribution')

# %%
sns.scatterplot(data = df , x = 'CreditScore' , y = 'Age' , hue = 'Exited')
plt.title('Credit Score vs Age')
# Out:
# Text(0.5, 1.0, 'Credit Score vs Age')

# %%
sns.boxplot ( x = 'Exited' , y = 'Balance' , data = df)
plt.title('Balance Distribution by Churn')
# Out:
# Text(0.5, 1.0, 'Balance Distribution by Churn')

# %%
sns.boxplot ( x = 'Exited' , y = 'CreditScore' , data = df)
plt.title('Credit Score Distribution by Churn')
# Out:
# Text(0.5, 1.0, 'Credit Score Distribution by Churn')

# %%
features=df.drop('Exited',axis=1)

# %%
features
# Out:
#       RowNumber  CustomerId     Surname  CreditScore  Geography  Gender  Age  \
# 0             1    15261344         Kai          619      Japan    Male   38
# 1             2    15172846       Matty          608  Australia    Male   37
# 2             3    15207294       Motts          502      Japan    Male   38
# 3             4    15845928     SLeeeng          699      Japan    Male   39
# 4             5    15638792   SStevieun          850  Australia    Male   43
# ...         ...         ...         ...          ...        ...     ...  ...
# 3994       3995    15763097   Siciliano          809  Australia  Female   80
# 3995       3996    15633666     Efremov          701  Australia    Male   33
# 3996       3997    15718789  Brigstocke          604      Japan  Female   30
# 3997       3998    15690620  Olisaemeka          665      Japan  Female   39
# 3998       3999    15737071        Tang          639      Japan    Male   60
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          5       0.00              1          1               1
# 1          2   83807.86              1          0               1
# 2          4  159660.80              1          1               0
# 3          2       0.00              4          0               0
# 4          5  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 3994       4       0.00              4          0               1
# 3995       7  123870.07              1          1               0
# 3996       5       0.00              4          1               0
# 3997      20   46323.57              1          1               0
# 3998       5  162039.78              1          1               1
#
#       EstimatedSalary
# 0           101348.88
# 1           112542.58
# 2           113931.57
# 3            93826.63
# 4            79084.10
# ...               ...
# 3994         34164.05
# 3995         97794.71
# 3996         75786.55
# 3997        136812.02
# 3998         84361.72
#
# [3999 rows x 13 columns]

# %%
target=df["Exited"]

# %%
target
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 3994    0
# 3995    0
# 3996    0
# 3997    0
# 3998    1
# Name: Exited, Length: 3999, dtype: int64

# %%
features=features.drop(["RowNumber","CustomerId", "Surname"], axis=1)

# %%
features
# Out:
#       CreditScore  Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619      Japan    Male   38       5       0.00              1
# 1             608  Australia    Male   37       2   83807.86              1
# 2             502      Japan    Male   38       4  159660.80              1
# 3             699      Japan    Male   39       2       0.00              4
# 4             850  Australia    Male   43       5  125510.82              1
# ...           ...        ...     ...  ...     ...        ...            ...
# 3994          809  Australia  Female   80       4       0.00              4
# 3995          701  Australia    Male   33       7  123870.07              1
# 3996          604      Japan  Female   30       5       0.00              4
# 3997          665      Japan  Female   39      20   46323.57              1
# 3998          639      Japan    Male   60       5  162039.78              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary
# 0             1               1        101348.88
# 1             0               1        112542.58
# 2             1               0        113931.57
# 3             0               0         93826.63
# 4             1               1         79084.10
# ...         ...             ...              ...
# 3994          0               1         34164.05
# 3995          1               0         97794.71
# 3996          1               0         75786.55
# 3997          1               0        136812.02
# 3998          1               1         84361.72
#
# [3999 rows x 10 columns]

# %%
features = features.dropna()

# %%
features
# Out:
#       CreditScore  Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619      Japan    Male   38       5       0.00              1
# 1             608  Australia    Male   37       2   83807.86              1
# 2             502      Japan    Male   38       4  159660.80              1
# 3             699      Japan    Male   39       2       0.00              4
# 4             850  Australia    Male   43       5  125510.82              1
# ...           ...        ...     ...  ...     ...        ...            ...
# 3994          809  Australia  Female   80       4       0.00              4
# 3995          701  Australia    Male   33       7  123870.07              1
# 3996          604      Japan  Female   30       5       0.00              4
# 3997          665      Japan  Female   39      20   46323.57              1
# 3998          639      Japan    Male   60       5  162039.78              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary
# 0             1               1        101348.88
# 1             0               1        112542.58
# 2             1               0        113931.57
# 3             0               0         93826.63
# 4             1               1         79084.10
# ...         ...             ...              ...
# 3994          0               1         34164.05
# 3995          1               0         97794.71
# 3996          1               0         75786.55
# 3997          1               0        136812.02
# 3998          1               1         84361.72
#
# [3999 rows x 10 columns]

# %%
features = pd.get_dummies(features , columns=['Geography' , 'Gender'])
features
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   38       5       0.00              1          1
# 1             608   37       2   83807.86              1          0
# 2             502   38       4  159660.80              1          1
# 3             699   39       2       0.00              4          0
# 4             850   43       5  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 3994          809   80       4       0.00              4          0
# 3995          701   33       7  123870.07              1          1
# 3996          604   30       5       0.00              4          1
# 3997          665   39      20   46323.57              1          1
# 3998          639   60       5  162039.78              1          1
#
#       IsActiveMember  EstimatedSalary  Geography_Australia  Geography_Japan  \
# 0                  1        101348.88                False             True
# 1                  1        112542.58                 True            False
# 2                  0        113931.57                False             True
# 3                  0         93826.63                False             True
# 4                  1         79084.10                 True            False
# ...              ...              ...                  ...              ...
# 3994               1         34164.05                 True            False
# 3995               0         97794.71                 True            False
# 3996               0         75786.55                False             True
# 3997               0        136812.02                False             True
# 3998               1         84361.72                False             True
#
#       Geography_USA  Gender_Female  Gender_Male
# 0             False          False         True
# 1             False          False         True
# 2             False          False         True
# 3             False          False         True
# 4             False          False         True
# ...             ...            ...          ...
# 3994          False           True        False
# 3995          False          False         True
# 3996          False           True        False
# 3997          False           True        False
# 3998          False          False         True
#
# [3999 rows x 13 columns]

# %%
from sklearn.model_selection import  train_test_split
from sklearn.preprocessing import StandardScaler

# %%
X_train , X_test , y_train , y_test = train_test_split(features , target , test_size=0.2 , random_state=42)

# %%
scalar = StandardScaler()
X_train = scalar.fit_transform(X_train)
X_test = scalar.fit_transform(X_test)

# %%
X_train
# Out:
# array([[-1.07805493, -1.46651461, -0.13941815, ..., -0.57891442,
#          0.93314534, -0.93314534],
#        [ 0.40385456, -0.81098   ,  0.35807059, ...,  1.72737104,
#          0.93314534, -0.93314534],
#        [-0.97655428,  2.18574963,  3.59174738, ...,  1.72737104,
#         -1.07164442,  1.07164442],
#        ...,
#        [ 0.160253  ,  0.40644141, -0.38816252, ..., -0.57891442,
#          0.93314534, -0.93314534],
#        [ 1.1143591 , -0.2490932 ,  0.85555933, ..., -0.57891442,
#          0.93314534, -0.93314534],
#        [-0.75325285,  0.40644141,  0.10932622, ..., -0.57891442,
#          0.93314534, -0.93314534]])

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score , classification_report , confusion_matrix
import pickle
import xgboost as xgb
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier

# %%
lr_model = LogisticRegression(random_state= 42)
lr_model.fit(X_train , y_train)
# Out:
# LogisticRegression(random_state=42)

# %%
lr_predictions = lr_model.predict(X_test)
lr_accuracy  = accuracy_score(y_test , lr_predictions)
lr_accuracy
# Out:
# 0.82625

# %%
def evaluate_and_save_model(model , X_train , X_test , y_train , y_test , filename):
    model.fit(X_train , y_train)
    y_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test , y_pred)

    print(f"{model.__class__.__name__} Accuracy: {accuracy:.4f}")
    print(f"\nClassification Report:\n{classification_report(y_test , y_pred)}")
    print("---------------")

    with open(filename , 'wb') as file:
      pickle.dump(model , file)
    print(f"File saved as {filename}")

# %%
xgb_model = xgb.XGBClassifier(random_state = 42)
evaluate_and_save_model(xgb_model ,X_train , X_test , y_train , y_test ,'xgb_model.pkl' )

dt_model = DecisionTreeClassifier(random_state = 42)
evaluate_and_save_model(dt_model ,X_train , X_test , y_train , y_test ,'dt_model.pkl' )

rf_model = RandomForestClassifier(random_state = 42)
evaluate_and_save_model(rf_model ,X_train , X_test , y_train , y_test ,'rf_model.pkl' )

nb_model = GaussianNB()
evaluate_and_save_model(nb_model ,X_train , X_test , y_train , y_test ,'nb_model.pkl' )

knn_model = KNeighborsClassifier()
evaluate_and_save_model(knn_model ,X_train , X_test , y_train , y_test ,'knn_model.pkl' )

svm_model = SVC(probability=True,random_state = 42)
evaluate_and_save_model(svm_model ,X_train , X_test , y_train , y_test ,'svm_model.pkl' )
# Out:
# XGBClassifier Accuracy: 0.7475
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.82      0.83       621
#            1       0.44      0.49      0.47       179
#
#     accuracy                           0.75       800
#    macro avg       0.65      0.66      0.65       800
# weighted avg       0.76      0.75      0.75       800
#
# ---------------
# File saved as xgb_model.pkl
# DecisionTreeClassifier Accuracy: 0.7913
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.86      0.87       621
#            1       0.53      0.54      0.53       179
#
#     accuracy                           0.79       800
#    macro avg       0.70      0.70      0.70       800
# weighted avg       0.79      0.79      0.79       800
#
# ---------------
# File saved as dt_model.pkl
# RandomForestClassifier Accuracy: 0.8375
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.96      0.90       621
#            1       0.76      0.40      0.53       179
#
#     accuracy                           0.84       800
#    macro avg       0.80      0.68      0.71       800
# weighted avg       0.83      0.84      0.82       800
#
# ---------------
# File saved as rf_model.pkl
# GaussianNB Accuracy: 0.8225
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.92      0.89       621
#            1       0.64      0.47      0.54       179
#
#     accuracy                           0.82       800
#    macro avg       0.75      0.70      0.72       800
# weighted avg       0.81      0.82      0.81       800
#
# ---------------
# File saved as nb_model.pkl
# KNeighborsClassifier Accuracy: 0.8200
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.95      0.89       621
#            1       0.68      0.37      0.48       179
#
#     accuracy                           0.82       800
#    macro avg       0.76      0.66      0.69       800
# weighted avg       0.80      0.82      0.80       800
#
# ---------------
# File saved as knn_model.pkl
# SVC Accuracy: 0.8413
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.98      0.91       621
#            1       0.82      0.37      0.51       179
#
#     accuracy                           0.84       800
#    macro avg       0.83      0.67      0.71       800
# weighted avg       0.84      0.84      0.82       800
#
# ---------------
# File saved as svm_model.pkl

# %%
feature_importances = xgb_model.feature_importances_
feature_names = features.columns

# %%
feature_importances
# Out:
# array([0.03994782, 0.09319484, 0.03862017, 0.05242039, 0.35450724,
#        0.04068631, 0.13577317, 0.03577282, 0.04089937, 0.04227081,
#        0.06850654, 0.05740053, 0.        ], dtype=float32)

# %%
feature_names
# Out:
# Index(['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Geography_Australia',
#        'Geography_Japan', 'Geography_USA', 'Gender_Female', 'Gender_Male'],
#       dtype='object')

# %%
feature_importances_df = pd.DataFrame({ 'feature' : feature_names, 'importance': feature_importances })
feature_importances_df
# Out:
#                 feature  importance
# 0           CreditScore    0.039948
# 1                   Age    0.093195
# 2                Tenure    0.038620
# 3               Balance    0.052420
# 4         NumOfProducts    0.354507
# 5             HasCrCard    0.040686
# 6        IsActiveMember    0.135773
# 7       EstimatedSalary    0.035773
# 8   Geography_Australia    0.040899
# 9       Geography_Japan    0.042271
# 10        Geography_USA    0.068507
# 11        Gender_Female    0.057401
# 12          Gender_Male    0.000000

# %%
feature_importances_df=feature_importances_df.sort_values('importance',ascending=False)

# %%
feature_importances_df
# Out:
#                 feature  importance
# 4         NumOfProducts    0.354507
# 6        IsActiveMember    0.135773
# 1                   Age    0.093195
# 10        Geography_USA    0.068507
# 11        Gender_Female    0.057401
# 3               Balance    0.052420
# 9       Geography_Japan    0.042271
# 8   Geography_Australia    0.040899
# 5             HasCrCard    0.040686
# 0           CreditScore    0.039948
# 2                Tenure    0.038620
# 7       EstimatedSalary    0.035773
# 12          Gender_Male    0.000000

# %%
plt.figure(figsize=(10,5))
plt.bar(feature_importances_df['feature'] , feature_importances_df['importance'])
plt.xticks(rotation = 90)
plt.xlabel('Features')
plt.ylabel('Importance')
plt.tight_layout()
plt.show()

# %%
features
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   38       5       0.00              1          1
# 1             608   37       2   83807.86              1          0
# 2             502   38       4  159660.80              1          1
# 3             699   39       2       0.00              4          0
# 4             850   43       5  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 3994          809   80       4       0.00              4          0
# 3995          701   33       7  123870.07              1          1
# 3996          604   30       5       0.00              4          1
# 3997          665   39      20   46323.57              1          1
# 3998          639   60       5  162039.78              1          1
#
#       IsActiveMember  EstimatedSalary  Geography_Australia  Geography_Japan  \
# 0                  1        101348.88                False             True
# 1                  1        112542.58                 True            False
# 2                  0        113931.57                False             True
# 3                  0         93826.63                False             True
# 4                  1         79084.10                 True            False
# ...              ...              ...                  ...              ...
# 3994               1         34164.05                 True            False
# 3995               0         97794.71                 True            False
# 3996               0         75786.55                False             True
# 3997               0        136812.02                False             True
# 3998               1         84361.72                False             True
#
#       Geography_USA  Gender_Female  Gender_Male
# 0             False          False         True
# 1             False          False         True
# 2             False          False         True
# 3             False          False         True
# 4             False          False         True
# ...             ...            ...          ...
# 3994          False           True        False
# 3995          False          False         True
# 3996          False           True        False
# 3997          False           True        False
# 3998          False          False         True
#
# [3999 rows x 13 columns]

# %%
features['CLV'] = df['Balance'] * df['EstimatedSalary'] / 100000

# %%
features
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   38       5       0.00              1          1
# 1             608   37       2   83807.86              1          0
# 2             502   38       4  159660.80              1          1
# 3             699   39       2       0.00              4          0
# 4             850   43       5  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 3994          809   80       4       0.00              4          0
# 3995          701   33       7  123870.07              1          1
# 3996          604   30       5       0.00              4          1
# 3997          665   39      20   46323.57              1          1
# 3998          639   60       5  162039.78              1          1
#
#       IsActiveMember  EstimatedSalary  Geography_Australia  Geography_Japan  \
# 0                  1        101348.88                False             True
# 1                  1        112542.58                 True            False
# 2                  0        113931.57                False             True
# 3                  0         93826.63                False             True
# 4                  1         79084.10                 True            False
# ...              ...              ...                  ...              ...
# 3994               1         34164.05                 True            False
# 3995               0         97794.71                 True            False
# 3996               0         75786.55                False             True
# 3997               0        136812.02                False             True
# 3998               1         84361.72                False             True
#
#       Geography_USA  Gender_Female  Gender_Male            CLV
# 0             False          False         True       0.000000
# 1             False          False         True   94319.527887
# 2             False          False         True  181904.056115
# 3             False          False         True       0.000000
# 4             False          False         True   99259.102400
# ...             ...            ...          ...            ...
# 3994          False           True        False       0.000000
# 3995          False          False         True  121138.375733
# 3996          False           True        False       0.000000
# 3997          False           True        False   63376.211853
# 3998          False          False         True  136699.545492
#
# [3999 rows x 14 columns]

# %%
features['AgeGroup'] = pd.cut(df['Age'], bins=[0, 30, 45, 60, 100], labels=['Young', 'Middleage', 'Senior', 'Elderly'])

# %%
features
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   38       5       0.00              1          1
# 1             608   37       2   83807.86              1          0
# 2             502   38       4  159660.80              1          1
# 3             699   39       2       0.00              4          0
# 4             850   43       5  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 3994          809   80       4       0.00              4          0
# 3995          701   33       7  123870.07              1          1
# 3996          604   30       5       0.00              4          1
# 3997          665   39      20   46323.57              1          1
# 3998          639   60       5  162039.78              1          1
#
#       IsActiveMember  EstimatedSalary  Geography_Australia  Geography_Japan  \
# 0                  1        101348.88                False             True
# 1                  1        112542.58                 True            False
# 2                  0        113931.57                False             True
# 3                  0         93826.63                False             True
# 4                  1         79084.10                 True            False
# ...              ...              ...                  ...              ...
# 3994               1         34164.05                 True            False
# 3995               0         97794.71                 True            False
# 3996               0         75786.55                False             True
# 3997               0        136812.02                False             True
# 3998               1         84361.72                False             True
#
#       Geography_USA  Gender_Female  Gender_Male            CLV   AgeGroup
# 0             False          False         True       0.000000  Middleage
# 1             False          False         True   94319.527887  Middleage
# 2             False          False         True  181904.056115  Middleage
# 3             False          False         True       0.000000  Middleage
# 4             False          False         True   99259.102400  Middleage
# ...             ...            ...          ...            ...        ...
# 3994          False           True        False       0.000000    Elderly
# 3995          False          False         True  121138.375733  Middleage
# 3996          False           True        False       0.000000      Young
# 3997          False           True        False   63376.211853  Middleage
# 3998          False          False         True  136699.545492     Senior
#
# [3999 rows x 15 columns]

# %%
features['TenureAgeRatio'] = df['Tenure'] / df['Age']

# %%
features
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   38       5       0.00              1          1
# 1             608   37       2   83807.86              1          0
# 2             502   38       4  159660.80              1          1
# 3             699   39       2       0.00              4          0
# 4             850   43       5  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 3994          809   80       4       0.00              4          0
# 3995          701   33       7  123870.07              1          1
# 3996          604   30       5       0.00              4          1
# 3997          665   39      20   46323.57              1          1
# 3998          639   60       5  162039.78              1          1
#
#       IsActiveMember  EstimatedSalary  Geography_Australia  Geography_Japan  \
# 0                  1        101348.88                False             True
# 1                  1        112542.58                 True            False
# 2                  0        113931.57                False             True
# 3                  0         93826.63                False             True
# 4                  1         79084.10                 True            False
# ...              ...              ...                  ...              ...
# 3994               1         34164.05                 True            False
# 3995               0         97794.71                 True            False
# 3996               0         75786.55                False             True
# 3997               0        136812.02                False             True
# 3998               1         84361.72                False             True
#
#       Geography_USA  Gender_Female  Gender_Male            CLV   AgeGroup  \
# 0             False          False         True       0.000000  Middleage
# 1             False          False         True   94319.527887  Middleage
# 2             False          False         True  181904.056115  Middleage
# 3             False          False         True       0.000000  Middleage
# 4             False          False         True   99259.102400  Middleage
# ...             ...            ...          ...            ...        ...
# 3994          False           True        False       0.000000    Elderly
# 3995          False          False         True  121138.375733  Middleage
# 3996          False           True        False       0.000000      Young
# 3997          False           True        False   63376.211853  Middleage
# 3998          False          False         True  136699.545492     Senior
#
#       TenureAgeRatio
# 0           0.131579
# 1           0.054054
# 2           0.105263
# 3           0.051282
# 4           0.116279
# ...              ...
# 3994        0.050000
# 3995        0.212121
# 3996        0.166667
# 3997        0.512821
# 3998        0.083333
#
# [3999 rows x 16 columns]

# %%
features = pd.get_dummies(features, drop_first=True)

# %%
features
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   38       5       0.00              1          1
# 1             608   37       2   83807.86              1          0
# 2             502   38       4  159660.80              1          1
# 3             699   39       2       0.00              4          0
# 4             850   43       5  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 3994          809   80       4       0.00              4          0
# 3995          701   33       7  123870.07              1          1
# 3996          604   30       5       0.00              4          1
# 3997          665   39      20   46323.57              1          1
# 3998          639   60       5  162039.78              1          1
#
#       IsActiveMember  EstimatedSalary  Geography_Australia  Geography_Japan  \
# 0                  1        101348.88                False             True
# 1                  1        112542.58                 True            False
# 2                  0        113931.57                False             True
# 3                  0         93826.63                False             True
# 4                  1         79084.10                 True            False
# ...              ...              ...                  ...              ...
# 3994               1         34164.05                 True            False
# 3995               0         97794.71                 True            False
# 3996               0         75786.55                False             True
# 3997               0        136812.02                False             True
# 3998               1         84361.72                False             True
#
#       Geography_USA  Gender_Female  Gender_Male            CLV  \
# 0             False          False         True       0.000000
# 1             False          False         True   94319.527887
# 2             False          False         True  181904.056115
# 3             False          False         True       0.000000
# 4             False          False         True   99259.102400
# ...             ...            ...          ...            ...
# 3994          False           True        False       0.000000
# 3995          False          False         True  121138.375733
# 3996          False           True        False       0.000000
# 3997          False           True        False   63376.211853
# 3998          False          False         True  136699.545492
#
#       TenureAgeRatio  AgeGroup_Middleage  AgeGroup_Senior  AgeGroup_Elderly
# 0           0.131579                True            False             False
# 1           0.054054                True            False             False
# 2           0.105263                True            False             False
# 3           0.051282                True            False             False
# 4           0.116279                True            False             False
# ...              ...                 ...              ...               ...
# 3994        0.050000               False            False              True
# 3995        0.212121                True            False             False
# 3996        0.166667               False            False             False
# 3997        0.512821                True            False             False
# 3998        0.083333               False             True             False
#
# [3999 rows x 18 columns]

# %%
X_train , X_test , y_train , y_test = train_test_split(features , target , test_size=0.2 , random_state=42)

# %%
X_train
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 1575          545   23       5       0.00              4          1
# 506           691   30       7  116927.89              1          1
# 3593          555   62      20  114822.64              1          0
# 3562          495   34       9  117160.32              1          1
# 3220          576   30       7  132174.41              4          0
# ...           ...  ...     ...        ...            ...        ...
# 1130          571   34       2  101736.66              1          0
# 1294          824   30       0  133634.02              1          1
# 860           667   43       4  190227.46              1          1
# 3507          761   36       9  127637.92              1          1
# 3174          577   43       6       0.00              4          1
#
#       IsActiveMember  EstimatedSalary  Geography_Australia  Geography_Japan  \
# 1575               0        189613.12                False             True
# 506                0         21198.39                False            False
# 3593               1          8444.50                False            False
# 3562               1        116069.24                False            False
# 3220               0         93767.03                False            False
# ...              ...              ...                  ...              ...
# 1130               1        195651.66                False            False
# 1294               1        162053.92                False             True
# 860                0         97508.04                False             True
# 3507               1         81062.93                False             True
# 3174               1        149457.81                 True            False
#
#       Geography_USA  Gender_Female  Gender_Male            CLV  \
# 1575          False           True        False       0.000000
# 506            True           True        False   24786.830141
# 3593           True          False         True    9696.197835
# 3562           True          False         True  135987.093006
# 3220           True           True        False  123936.018677
# ...             ...            ...          ...            ...
# 1130           True          False         True  199049.464119
# 1294          False           True        False  216559.167864
# 860           False           True        False  185487.067788
# 3507          False           True        False  103467.037743
# 3174          False           True        False       0.000000
#
#       TenureAgeRatio  AgeGroup_Middleage  AgeGroup_Senior  AgeGroup_Elderly
# 1575        0.217391               False            False             False
# 506         0.233333               False            False             False
# 3593        0.322581               False            False              True
# 3562        0.264706                True            False             False
# 3220        0.233333               False            False             False
# ...              ...                 ...              ...               ...
# 1130        0.058824                True            False             False
# 1294        0.000000               False            False             False
# 860         0.093023                True            False             False
# 3507        0.250000                True            False             False
# 3174        0.139535                True            False             False
#
# [3199 rows x 18 columns]

# %%
xgboost_model = xgb.XGBClassifier(random_state = 42)
evaluate_and_save_model(xgboost_model ,X_train , X_test , y_train , y_test ,'xgboost-featureEngineered.pkl' )
# Out:
# XGBClassifier Accuracy: 0.8425
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.95      0.90       621
#            1       0.73      0.47      0.57       179
#
#     accuracy                           0.84       800
#    macro avg       0.79      0.71      0.74       800
# weighted avg       0.83      0.84      0.83       800
#
# ---------------
# File saved as xgboost-featureEngineered.pkl

# %%
from imblearn.over_sampling import SMOTE

# %%
smote = SMOTE(random_state=42)

# %%
X_resampled , y_resampled = smote.fit_resample(X_train , y_train)

# %%
evaluate_and_save_model(xgboost_model ,X_resampled , X_test , y_resampled , y_test ,'xgboost-SMOTE.pkl')
# Out:
# XGBClassifier Accuracy: 0.8387
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.93      0.90       621
#            1       0.68      0.53      0.60       179
#
#     accuracy                           0.84       800
#    macro avg       0.78      0.73      0.75       800
# weighted avg       0.83      0.84      0.83       800
#
# ---------------
# File saved as xgboost-SMOTE.pkl

# %%
from sklearn.ensemble import VotingClassifier

# %%
voting_clf = VotingClassifier(
    estimators=  [('xgboost' , xgb.XGBClassifier(random_state = 42)), ('rf' , RandomForestClassifier(random_state = 42)),('svm' , SVC(random_state = 42 ,probability=True))],
    voting = 'hard'
)

# %%
evaluate_and_save_model(voting_clf ,X_resampled , X_test , y_resampled , y_test ,'voting_clf.pkl' )
# Out:
# VotingClassifier Accuracy: 0.8363
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.91      0.90       621
#            1       0.66      0.56      0.61       179
#
#     accuracy                           0.84       800
#    macro avg       0.77      0.74      0.75       800
# weighted avg       0.83      0.84      0.83       800
#
# ---------------
# File saved as voting_clf.pkl
